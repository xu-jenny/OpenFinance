# %%
import pandas as pd
df = pd.read_csv("co.csv")
df.head()
# Out:
#          companyName numAffected   workforce_region noticeDate layoff_reason  \
# 0    Albertsons #632          38        Mesa County   6/4/2015       Closure
# 1   Albertsons #8584          78  Pikes Peak/Teller  3/24/2015       Closure
# 2  Ambassadors Group           1             Denver  4/27/2015      Downsize
# 3  Baker Hughes Inc.          17       Adams County  9/30/2015      Downsize
# 4  Baker Hughes Inc.         124       Adams County  8/12/2015      Downsize
#
#   Occupations layoffDate Temp Layoffs Perm Layoffs Furloughs WARN Letter  \
# 0         NaN        NaN          NaN          NaN       NaN         NaN
# 1         NaN        NaN          NaN          NaN       NaN         NaN
# 2         NaN        NaN          NaN          NaN       NaN         NaN
# 3         NaN        NaN          NaN          NaN       NaN         NaN
# 4         NaN        NaN          NaN          NaN       NaN         NaN
#
#   NAICS
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
regex = r'\d{1,2}/\d{1,2}/\d{4}'
df[~df['noticeDate'].str.match(regex)]
# Out:
#                                    companyName numAffected workforce_region  \
# 170                       Conagra Brands, Inc.         100          Boulder
# 192                           Peak Reliability          69          Larimer
# 195  Sandoz Inc., A Novartis Division (Update)          24       Broomfield
# 210                       Conagra Brands, Inc.         100          Boulder
# 215                                HomeAdvisor         229       Pikes Peak
# ..                                         ...         ...              ...
# 632                     Davids Bridal (Update)         ?*        Multi area
# 633                          MV Transportation         198          Denver
# 634                      Via Mobility Services         120           Denver
# 635                                    Amentum          19           Pueblo
# 636           Hard Rock Cafe International STD          54           Denver
#
#                                             noticeDate         layoff_reason  \
# 170                               05/24/19 - 3/20/2020               Closure
# 192                                  1/7/19 & 4/6/2020  Terminate Operations
# 195                                  1/7/19 & 4/6/2020               Closure
# 210                                             2/5/19               Closure
# 215  11-1-19 received 11/19/19 via Local Area/Suthe...               Closure
# ..                                                 ...                   ...
# 632                                            5/24/23             Bankrupcy
# 633                                            4/27/23         Not specified
# 634                                             5/1/23      Loss of Contract
# 635                                            5/26/23     Closure (Phase 1)
# 636                                            5/30/23              Closure
#
#                                            Occupations         layoffDate  \
# 170                                                NaN                NaN
# 192                                                NaN                NaN
# 195                                                NaN                NaN
# 210                                       Not reported  5/24/19 - 3/20/20
# 215  Various: Predominately Sales Consultants and P...  1/1/20 to 1/14/20
# ..                                                 ...                ...
# 632                                 Various (See WARN)            6/23/23
# 633        Drivers, Dispatchers, Admin, Utility Worker            6/30/23
# 634  Administrative support, operatives,  & service...           7/1/2023
# 635  Engineers, Maintenace Planners/Supervisors, Te...          7/27/2023
# 636                                 Restaurant workers          7/29/2023
#
#     Temp Layoffs Perm Layoffs Furloughs            WARN Letter  \
# 170          NaN          NaN       NaN                    NaN
# 192          NaN          NaN       NaN                    NaN
# 195          NaN          NaN       NaN                    NaN
# 210          NaN          NaN       NaN                    NaN
# 215          NaN          NaN       NaN                    NaN
# ..           ...          ...       ...                    ...
# 632            0           ?*         0   Davids Bridal Update
# 633            0          198         0      MV Transportation
# 634            0          120         0  Via Mobility Services
# 635            0           19         0                Amentum
# 636            0           54         0         Hard Rock Cafe
#
#                                        NAICS
# 170                                       NaN
# 192                                       NaN
# 195                                       NaN
# 210                                       NaN
# 215                                       NaN
# ..                                        ...
# 632                   Sector 44: Retail Trade
# 633   Sector 48: Transportation & Warehousing
# 634  Sector 48: Transporation and Warehousing
# 635     Sector: 56,2910: Remediation Services
# 636  Sector 72: Accommodation & Food Services
#
# [94 rows x 12 columns]

# %%
def is_standard_date(date):
    try:
        # Try to convert the string to a datetime object
        pd.to_datetime(date)
        return True
    except ValueError:
        # If it fails, it's not a standard date
        return False

# Create a boolean mask where each value is True if the date is not standard and False otherwise
mask = ~df['noticeDate'].apply(is_standard_date)
df[mask]
# Out:
#                                    companyName numAffected  \
# 170                       Conagra Brands, Inc.         100
# 192                           Peak Reliability          69
# 195  Sandoz Inc., A Novartis Division (Update)          24
# 215                                HomeAdvisor         229
# 216             Invesco (OppenheimerFunds OFI)         850
# 220            National Express Transit (NEXT)          60
# 223         PrimeFlight Aviation Services Inc.         439
# 229  Sandoz Inc., A Novartis Division (Update)          24
# 230                            Sandoz-Novartis          24
#
#                   workforce_region  \
# 170                        Boulder
# 192                        Larimer
# 195                     Broomfield
# 215                     Pikes Peak
# 216  Arapahoe/Douglas (Centennial)
# 220                     Pikes Peak
# 223                         Denver
# 229                     Broomfield
# 230                     Broomfield
#
#                                             noticeDate  \
# 170                               05/24/19 - 3/20/2020
# 192                                  1/7/19 & 4/6/2020
# 195                                  1/7/19 & 4/6/2020
# 215  11-1-19 received 11/19/19 via Local Area/Suthe...
# 216                        3/21/19 (received  3/22/19)
# 220                       3/1/19 (received on 3/22/19)
# 223                         7/15/19 (received 7/16/19)
# 229                                  1/7/19 & 4/6/2020
# 230                                     7/6/19-7/31/19
#
#                              layoff_reason  \
# 170                                Closure
# 192                   Terminate Operations
# 195                                Closure
# 215                                Closure
# 216                             Downsizing
# 220                                Closure
# 223  Loss of Contract with United Airlines
# 229                                Closure
# 230                                Closure
#
#                                            Occupations  \
# 170                                                NaN
# 192                                                NaN
# 195                                                NaN
# 215  Various: Predominately Sales Consultants and P...
# 216                              Not disclosed in WARN
# 220  3 Managers and 57 hourly employees including G...
# 223  Various positions: Cabin Appearance Staff (380...
# 229           Production Technicians, Chemists, & more
# 230  Lead Technicians (5), Equipment Maintenance Te...
#
#                          layoffDate Temp Layoffs Perm Layoffs Furloughs  \
# 170                             NaN          NaN          NaN       NaN
# 192                             NaN          NaN          NaN       NaN
# 195                             NaN          NaN          NaN       NaN
# 215               1/1/20 to 1/14/20          NaN          NaN       NaN
# 216  5/25/19 (thru 18 mo following)          NaN          NaN       NaN
# 220                         6/30/19          NaN          NaN       NaN
# 223                         9/18/19          NaN          NaN       NaN
# 229                 4/13/19-5/30/19          NaN          NaN       NaN
# 230                7/6/19 - 7/31/19          NaN          NaN       NaN
#
#     WARN Letter NAICS
# 170         NaN    NaN
# 192         NaN    NaN
# 195         NaN    NaN
# 215         NaN    NaN
# 216         NaN    NaN
# 220         NaN    NaN
# 223         NaN    NaN
# 229         NaN    NaN
# 230         NaN    NaN

# %% [markdown]
# there's not enough records for me to create a script. i'll just manually edit them in csv

# %%
df.isna().sum()
# Out:
# companyName           0
# numAffected          12
# workforce_region      0
# noticeDate            0
# layoff_reason         1
# Occupations         213
# layoffDate          220
# Temp Layoffs        380
# Perm Layoffs        453
# Furloughs           446
# WARN Letter         270
# NAICS               244
# dtype: int64

# %%
df['noticeDate'] = df['numAffected'].str.split(' - ').str[1]

# %%
df['numAffected'] = df['numAffected'].fillna(df['Perm Layoffs'])

# %%
df[df['numAffected'].isna()]
# Out:
#                                            companyName numAffected  \
# 28                 Lockheed Martin-Rev to 7/20/15 WARN         NaN
# 52   Sinton Dairy Foods Company/ Borden-Rev to 3/16/15         NaN
# 53   Sinton Dairy Foods Company/ Borden-Rev to 3/16/15         NaN
# 54   Sinton Dairy Foods Company/ Borden-Rev to 3/16/15         NaN
# 55   Sinton Dairy Foods Company/ Borden-Rev to 3/16/15         NaN
# 76   Climax Molybdenum Co - Henderson Mine & Mill -...         NaN
# 90                                    Sports Authority         NaN
# 91   Climax Molybdenum Co - Henderson Mine & Mill -...         NaN
# 92                                    Sports Authority         NaN
# 107  Sky Hotel 39 Degrees Recinds Layoffs from 2/5/...         NaN
# 112  Climax Molybdenum Co - Henderson Mine & Mill -...         NaN
#
#       workforce_region  noticeDate layoff_reason Occupations layoffDate  \
# 28   Pikes Peak/Teller         NaN      Downsize         NaN        NaN
# 52   Pikes Peak/Teller         NaN       Closure         NaN        NaN
# 53   Pikes Peak/Teller         NaN       Closure         NaN        NaN
# 54   Pikes Peak/Teller         NaN       Closure         NaN        NaN
# 55   Pikes Peak/Teller         NaN       Closure         NaN        NaN
# 76           Jefferson         NaN      Revision         NaN        NaN
# 90    Arapahoe/Douglas         NaN      Revision         NaN        NaN
# 91           Jefferson         NaN      Revision         NaN        NaN
# 92    Arapahoe/Douglas         NaN      Revision         NaN        NaN
# 107       Rural Resort         NaN           NaN         NaN        NaN
# 112          Jefferson         NaN      Downsize         NaN        NaN
#
#     Temp Layoffs Perm Layoffs Furloughs WARN Letter NAICS
# 28           NaN          NaN       NaN         NaN    NaN
# 52           NaN          NaN       NaN         NaN    NaN
# 53           NaN          NaN       NaN         NaN    NaN
# 54           NaN          NaN       NaN         NaN    NaN
# 55           NaN          NaN       NaN         NaN    NaN
# 76           NaN          NaN       NaN         NaN    NaN
# 90           NaN          NaN       NaN         NaN    NaN
# 91           NaN          NaN       NaN         NaN    NaN
# 92           NaN          NaN       NaN         NaN    NaN
# 107          NaN          NaN       NaN         NaN    NaN
# 112          NaN          NaN       NaN         NaN    NaN

# %%
df = df.dropna(subset=['numAffected'])

# %%
df.isna().sum()
# Out:
# companyName           0
# numAffected           0
# workforce_region      0
# noticeDate          626
# layoff_reason         0
# Occupations         202
# layoffDate          209
# Temp Layoffs        369
# Perm Layoffs        442
# Furloughs           435
# WARN Letter         259
# NAICS               233
# dtype: int64

# %%
df.to_csv('co_processed.csv')
